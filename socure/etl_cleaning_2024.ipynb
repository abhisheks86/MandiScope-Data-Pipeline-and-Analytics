# %%
import pandas as pd 
df = pd.read_csv("raw_2024.csv")
display(df.head())
print(df.shape)
print(df.dtypes)

null_counts = df.isna().sum()
null_percentages = (null_counts/len(df))*100
missing_data = pd.DataFrame({'Missing_Rows':null_counts,'Missing_%':null_percentages})

print(missing_data[missing_data['Missing_Rows'] > 0].sort_values(by='Missing_Rows', ascending=False))

numeric_cols = ['Min_Price','Max_Price','Modal_Price']
print(df[numeric_cols].describe().T[['min','max','mean','50%']])
math = df[df['Min_Price']>df['Max_Price']]
print(f"\nAlert: Found {len(math):,} rows where Min_Price > Max_Price!")
zero_prices = df[df['Modal_Price']<=0]
print(f"Alert:found{len(zero_prices):,}rows with a Model_Price of 0 or negative!")


for col in ['STATE','Commodity']:unique_count = df[col].nunique()
print(f"\n column [{col}] has {unique_count}distinct spellings.")
print(df[col].value_counts().head(10))

#Clean
text_cols = ['STATE', 'District Name', 'Market Name', 'Commodity', 'Variety', 'Grade']
for col in text_cols:
    df[col] = df[col].fillna("UNKNOWN")
    df[col] = df[col].astype(str).str.strip().str.upper()
df = df.dropna(subset=['Modal_Price', 'Min_Price', 'Max_Price'])
df = df[(df['Min_Price'] > 0) & (df['Max_Price'] > 0) & (df['Modal_Price'] > 0)]
df = df[df['Min_Price'] < 100000]
df = df[df['Max_Price'] >= df['Min_Price']]

#verify 
print(f"Cleaned Row Count: {len(df):,}")
rows_removed = 256506 - len(df) 
print(f"Total Garbage Rows Purged: {rows_removed:,}")
print(df[['Min_Price', 'Max_Price', 'Modal_Price']].describe().T[['min', 'max']])

null_check = df.isna().sum()
remaining = null_check[null_check > 0]
if len(remaining) == 0:
    print("Zero nulls remaining — data is clean")
else:
    print(remaining)
bad_math = df[df['Min_Price'] > df['Max_Price']]
print(f"Min > Max remaining: {len(bad_math)}")

#Save 
df.to_csv("Clean_Mandi_2024.csv", index=False)
print("Saved file")
# Out:
#              STATE District Name    Market Name Commodity Variety Grade  \
# 0              Nan        hardoi         Hardoi       NaN    Dara   FAQ
# 1   Uttar Pradesh            NaN      Barabanki     Onion     Red   FAQ
# 2           Kerala      kottayam  Kanjirappally       NaN  Potato   FAQ
# 3              NaN           NaN            NaN       NaN   Other   FAQ
# 4    Uttar Pradesh           NaN            NaN     Onion     Red   FAQ
#
#    Min_Price  Max_Price  Modal_Price  Price Date
# 0     2380.0        NaN       2440.0  01-01-2024
# 1      770.0      870.0        820.0  01-01-2024
# 2        NaN        NaN          NaN  01-01-2024
# 3     1800.0        NaN          NaN  01-01-2024
# 4     2150.0     2260.0          NaN  01-01-2024
# (256506, 10)
# STATE                str
# District Name        str
# Market Name          str
# Commodity            str
# Variety              str
# Grade                str
# Min_Price        float64
# Max_Price        float64
# Modal_Price      float64
# Price Date           str
# dtype: object
#                Missing_Rows  Missing_%
# Max_Price             64506  25.147950
# Commodity             64330  25.079335
# Modal_Price           64143  25.006433
# Market Name           64104  24.991228
# Min_Price             64091  24.986160
# District Name         64089  24.985380
# Variety               63966  24.937428
# Grade                 63859  24.895714
# STATE                 52006  20.274769
#               min       max         mean     50%
# Min_Price     0.0  240000.0  2461.727578  2100.0
# Max_Price     0.0   64000.0  2959.640349  2500.0
# Modal_Price  10.0  240000.0  2772.942195  2312.0
#
# Alert: Found 88 rows where Min_Price > Max_Price!
# Alert:found0rows with a Model_Price of 0 or negative!
#
#  column [Commodity] has 3distinct spellings.
# Commodity
# Potato    98660
# Onion     87792
# Wheat      5724
# Name: count, dtype: int64
# Cleaned Row Count: 108,197
# Total Garbage Rows Purged: 148,309
#               min      max
# Min_Price     2.0  58500.0
# Max_Price    10.0  60000.0
# Modal_Price  10.0  58540.0
# Zero nulls remaining — data is clean
# Min > Max remaining: 0
# Saved file
