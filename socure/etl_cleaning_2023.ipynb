# %%
import pandas as pd 
df = pd.read_csv("raw_2023.csv")
display(df.head())
print(df.shape)
print(df.dtypes)

null_counts = df.isna().sum()
null_percentages = (null_counts/len(df))*100
missing_data = pd.DataFrame({'Missing_Rows':null_counts,'Missing_%':null_percentages})

print(missing_data[missing_data['Missing_Rows'] > 0].sort_values(by='Missing_Rows', ascending=False))

numeric_cols = ['Min_Price','Max_Price','Modal_Price']
print(df[numeric_cols].describe().T[['min','max','mean','50%']])
math = df[df['Min_Price']>df['Max_Price']]
print(f"\nAlert: Found {len(math):,} rows where Min_Price > Max_Price!")
zero_prices = df[df['Modal_Price']<=0]
print(f"Alert:found{len(zero_prices):,}rows with a Model_Price of 0 or negative!")


for col in ['STATE','Commodity']:unique_count = df[col].nunique()
print(f"\n column [{col}] has {unique_count}distinct spellings.")
print(df[col].value_counts().head(10))

#Clean
text_cols = ['STATE', 'District Name', 'Market Name', 'Commodity', 'Variety', 'Grade']
for col in text_cols:
    df[col] = df[col].fillna("UNKNOWN")
    df[col] = df[col].astype(str).str.strip().str.upper()
df = df.dropna(subset=['Modal_Price', 'Min_Price', 'Max_Price'])
df = df[(df['Min_Price'] > 0) & (df['Max_Price'] > 0) & (df['Modal_Price'] > 0)]
df = df[df['Min_Price'] < 100000]
df = df[df['Max_Price'] >= df['Min_Price']]

#verify 
print(f"Cleaned Row Count: {len(df):,}")
rows_removed = 216193 - len(df) 
print(f"Total Garbage Rows Purged: {rows_removed:,}")
print(df[['Min_Price', 'Max_Price', 'Modal_Price']].describe().T[['min', 'max']])

null_check = df.isna().sum()
remaining = null_check[null_check > 0]
if len(remaining) == 0:
    print("Zero nulls remaining — data is clean")
else:
    print(remaining)
bad_math = df[df['Min_Price'] > df['Max_Price']]
print(f"Min > Max remaining: {len(bad_math)}")

#Save 
df.to_csv("Clean_Mandi_2023.csv", index=False)
print("Saved file")
# Out:
#            STATE District Name        Market Name Commodity           Variety  \
# 0    Maharashtra        nashik  Lasalgaon(Niphad)     Wheat  Maharashtra 2189
# 1    Maharashtra           NaN              Patan    Tomato             Other
# 2  uttar pradesh      mainpuri                NaN    Potato               NaN
# 3      Rajasthan           NaN         Pratapgarh       NaN             Other
# 4        Haryana        ambala                NaN       NaN               NaN
#
#   Grade  Min_Price  Max_Price  Modal_Price  Price Date
# 0   FAQ        NaN        NaN          NaN  06-06-2023
# 1   FAQ     1000.0     1500.0          NaN  06-06-2023
# 2   NaN      800.0      820.0          NaN  06-06-2023
# 3   FAQ      476.0        NaN        617.0  06-06-2023
# 4   FAQ      500.0      800.0        700.0  06-06-2023
# (216193, 10)
# STATE                str
# District Name        str
# Market Name          str
# Commodity            str
# Variety              str
# Grade                str
# Min_Price        float64
# Max_Price        float64
# Modal_Price      float64
# Price Date           str
# dtype: object
#                Missing_Rows  Missing_%
# Market Name           54375  25.151138
# Grade                 54317  25.124310
# Commodity             54283  25.108584
# Min_Price             54045  24.998497
# Max_Price             54039  24.995721
# Modal_Price           54001  24.978145
# District Name         53952  24.955480
# Variety               53849  24.907837
# STATE                 43877  20.295292
#              min       max         mean     50%
# Min_Price    0.0  420000.0  2091.523608  1940.0
# Max_Price    0.0  150000.0  2532.366127  2225.0
# Modal_Price  0.0  460000.0  2326.200023  2110.0
#
# Alert: Found 164 rows where Min_Price > Max_Price!
# Alert:found2rows with a Model_Price of 0 or negative!
#
#  column [Commodity] has 4distinct spellings.
# Commodity
# Onion     52760
# Potato    50906
# Wheat     41758
# Tomato    16486
# Name: count, dtype: int64
# Cleaned Row Count: 91,060
# Total Garbage Rows Purged: 125,133
#               min      max
# Min_Price     8.0  80000.0
# Max_Price    16.0  84000.0
# Modal_Price  14.0  82000.0
# Zero nulls remaining — data is clean
# Min > Max remaining: 0
# Saved file
