# %%
import pandas as pd
from sqlalchemy import create_engine

print("Reading CSV...")
df = pd.read_csv("Clean_Mandi_2026.csv") # Change to your exact file path
engine = create_engine("mysql+pymysql://root:abhiguru46@localhost:3306/mandi")
print("Uploading to MySQL...")
df.to_sql('pristine_mandi', con=engine, index=False, if_exists='replace')

print("CSV successfully loaded into MySQL!")
# Out:
# Reading CSV...
# Uploading to MySQL...
# CSV successfully loaded into MySQL!
